# %%
# imports and setup 
from bs4 import BeautifulSoup
# you can use either of these libraries to get html from a website
import requests
import urllib.request
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

import pandas as pd
import scipy as sc
import numpy as np
import time
import statsmodels.formula.api as sm

import matplotlib.pyplot as plt 
plt.style.use('ggplot')
# %matplotlib inline  
plt.rcParams['figure.figsize'] = (10, 6) 
from string import ascii_lowercase

# %%
career_pergame = pd.read_csv('career_pergame.csv',index_col=0)

# %%
career_per36 = pd.read_csv('career_per36.csv',index_col=0)

# %%
career_per100 = pd.read_csv('career_per100.csv',index_col=0)

# %%
career_advanced = pd.read_csv('career_advanced.csv',index_col=0)

# %%
career_pergame = career_pergame.set_index('Name')

# %%
career_per36 = career_per36.set_index('Name')

# %%
career_per100 = career_per100.set_index('Name')

# %%
career_advanced = career_advanced.set_index('Name')

# %%
dfs = [career_pergame,career_per36,career_per100,career_advanced]
career = dfs[0].join(dfs[1:])

# %%
cols = [c for c in career.columns if c.lower()[:5] != 'blank']

# %%
career = career[cols]

# %%
cols = [c for c in career.columns if c.lower()[len(c)-2:] != '_y']

# %%
career = career[cols]

# %%
career = career.loc[:,~career.columns.duplicated()]

# %%
career = career.drop('Year_x',axis=1)

# %%
career = career.drop('League_x',axis=1)

# %%
#Only want to run once for backup purposes
#career.to_csv('career.csv')

# %%
career['Percent_Games_Started'] = career['Games Started_x']/career['Games Played_x']

# %%
#rookie datasets
rookie_pergame = pd.read_csv('per_game.csv', index_col = 0)

# %%
rookie_per36 = pd.read_csv('per_36.csv', index_col = 0)

# %%
rookie_per100 = pd.read_csv('per_100.csv', index_col = 0)

# %%
rookie_advanced = pd.read_csv('rookie_advanced.csv', index_col = 0)

# %%
dfs = [rookie_pergame, rookie_per36, rookie_per100, rookie_advanced]
dfs = [df.set_index('Name') for df in dfs]
rookie = dfs[0].join(dfs[1:])

# %%
rookie
# Out:
#                      Year_x  Age_x Team_x League_x Position_x  Games Played_x  \
# Name
# A.C. Green          1985-86   22.0    LAL      NBA         PF              82
# A.J. Bramlett       1999-00   23.0    CLE      NBA          C               8
# A.J. English        1990-91   23.0    WSB      NBA         SG              70
# A.J. Guyton         2000-01   22.0    CHI      NBA         PG              33
# A.J. Hammons        2016-17   24.0    DAL      NBA          C              22
# A.J. Price          2009-10   23.0    IND      NBA         PG              56
# A.J. Wynder         1990-91   26.0    BOS      NBA         PG               6
# Aaron Brooks        2007-08   23.0    HOU      NBA         PG              51
# Aaron Gordon        2014-15   19.0    ORL      NBA         PF              47
# Aaron Gray          2007-08   23.0    CHI      NBA          C              61
# Aaron Harrison      2015-16   21.0    CHO      NBA         SG              21
# Aaron McKie         1994-95   22.0    POR      NBA         SG              45
# Aaron Miles         2005-06   22.0    GSW      NBA         PG              19
# Aaron Swinson       1994-95   24.0    PHO      NBA         SF               9
# Aaron Williams      1993-94   22.0    UTA      NBA         PF               6
# Abdel Nader         2017-18   24.0    BOS      NBA         SF              31
# Abdul Jeelani       1979-80   25.0    POR      NBA         SF              77
# Acie Earl           1993-94   23.0    BOS      NBA          C              74
# Acie Law            2007-08   23.0    ATL      NBA         PG              56
# Adam Harrington     2002-03   22.0    TOT      NBA         SG              19
# Adam Keefe          1992-93   22.0    ATL      NBA         PF              82
# Adam Morrison       2006-07   22.0    CHA      NBA         PF              78
# Adonal Foyle        1997-98   22.0    GSW      NBA          C              55
# Adonis Jordan       1993-94   23.0    DEN      NBA         PG               6
# Adonis Thomas       2013-14   20.0    TOT      NBA         SF               6
# Adreian Payne       2014-15   23.0    TOT      NBA         PF              32
# Adrian Branch       1986-87   23.0    LAL      NBA         SF              32
# Adrian Caldwell     1989-90   23.0    HOU      NBA         PF              51
# Adrian Dantley      1976-77   20.0    BUF      NBA         SF              77
# Adrian Griffin      1999-00   25.0    BOS      NBA         SG              72
# ...                     ...    ...    ...      ...        ...             ...
# Winston Crite       1987-88   22.0    PHO      NBA         SF              29
# Winston Garland     1987-88   23.0    GSW      NBA         PG              67
# World B. Free       1975-76   22.0    PHI      NBA         SG              71
# Xavier Henry        2010-11   19.0    MEM      NBA         SG              38
# Xavier McDaniel     1985-86   22.0    SEA      NBA         SF              82
# Xavier Munford      2015-16   23.0    MEM      NBA         SG              14
# Xavier Silas        2011-12   24.0    PHI      NBA         SG               2
# Yakhouba Diawara    2006-07   24.0    DEN      NBA         SG              64
# Yao Ming            2002-03   22.0    HOU      NBA          C              82
# Yaroslav Korolev    2005-06   18.0    LAC      NBA         SF              24
# Yi Jianlian         2007-08   20.0    MIL      NBA         PF              66
# Yinka Dare          1994-95   22.0    NJN      NBA          C               1
# Yogi Ferrell        2016-17   23.0    TOT      NBA         PG              46
# Yuta Tabuse         2004-05   24.0    PHO      NBA         PG               4
# Yvon Joseph         1985-86   28.0    NJN      NBA          C               1
# Zabian Dowdell      2010-11   26.0    PHO      NBA         PG              24
# Zach Collins        2017-18   20.0    POR      NBA          C              46
# Zach LaVine         2014-15   19.0    MIN      NBA         PG              77
# Zach Randolph       2001-02   20.0    POR      NBA         PF              41
# Zan Tabak           1994-95   24.0    HOU      NBA          C              37
# Zarko Cabarkapa     2003-04   22.0    PHO      NBA         PF              49
# Zarko Paspalj       1989-90   23.0    SAS      NBA         SF              28
# Zaza Pachulia       2003-04   19.0    ORL      NBA          C              59
# Zeljko Rebraca      2001-02   29.0    DET      NBA          C              74
# Zelmo Beaty         1962-63   23.0    STL      NBA          C              80
# Zendon Hamilton     2000-01   25.0    LAC      NBA          C               3
# Zhou Qi             2017-18   22.0    HOU      NBA          C              14
# Zoran Dragic        2014-15   25.0    TOT      NBA         SG              16
# Zoran Planinic      2003-04   21.0    NJN      NBA         SG              49
# Zydrunas Ilgauskas  1997-98   22.0    CLE      NBA          C              82
#
#                     Games Started_x  MinPerGame  FGPerGame  FGAPerGame  ...   \
# Name                                                                    ...
# A.C. Green                      1.0        18.8        2.5         4.7  ...
# A.J. Bramlett                   0.0         7.6        0.5         2.6  ...
# A.J. English                   12.0        20.6        3.6         8.2  ...
# A.J. Guyton                     8.0        19.1        2.4         5.8  ...
# A.J. Hammons                    0.0         7.4        0.8         1.9  ...
# A.J. Price                      2.0        15.4        2.6         6.3  ...
# A.J. Wynder                     0.0         6.5        0.5         2.0  ...
# Aaron Brooks                    0.0        11.9        1.8         4.4  ...
# Aaron Gordon                    8.0        17.0        2.0         4.4  ...
# Aaron Gray                      1.0        10.0        1.7         3.3  ...
# Aaron Harrison                  0.0         4.4        0.2         0.9  ...
# Aaron McKie                    20.0        18.4        2.6         5.8  ...
# Aaron Miles                     0.0         6.2        0.3         0.9  ...
# Aaron Swinson                   0.0         5.7        1.1         2.0  ...
# Aaron Williams                  0.0         2.0        0.3         1.3  ...
# Abdel Nader                     0.0         9.1        0.9         2.6  ...
# Abdul Jeelani                   NaN        16.7        3.7         7.3  ...
# Acie Earl                       8.0        15.5        2.0         5.0  ...
# Acie Law                        6.0        15.4        1.7         4.2  ...
# Adam Harrington                 0.0         5.8        0.6         1.9  ...
# Adam Keefe                      6.0        18.9        2.3         4.6  ...
# Adam Morrison                  23.0        29.8        4.6        12.1  ...
# Adonal Foyle                    1.0        11.9        1.3         3.1  ...
# Adonis Jordan                   0.0        13.2        1.0         3.8  ...
# Adonis Thomas                   1.0         6.2        1.0         2.3  ...
# Adreian Payne                  22.0        23.1        2.8         6.9  ...
# Adrian Branch                   0.0         6.8        1.5         3.0  ...
# Adrian Caldwell                 0.0         6.5        0.8         1.5  ...
# Adrian Dantley                  NaN        36.6        7.1        13.6  ...
# Adrian Griffin                 47.0        26.8        2.4         5.7  ...
# ...                             ...         ...        ...         ...  ...
# Winston Crite                   0.0         8.9        1.2         2.3  ...
# Winston Garland                62.0        31.7        5.1        11.6  ...
# World B. Free                   NaN        15.8        3.4         7.5  ...
# Xavier Henry                   16.0        13.9        1.7         4.2  ...
# Xavier McDaniel                80.0        33.0        7.0        14.3  ...
# Xavier Munford                  0.0        17.4        2.3         5.5  ...
# Xavier Silas                    0.0        19.5        2.0         7.5  ...
# Yakhouba Diawara               19.0        18.4        1.6         4.6  ...
# Yao Ming                       72.0        29.0        4.9         9.8  ...
# Yaroslav Korolev                0.0         5.3        0.4         1.3  ...
# Yi Jianlian                    49.0        25.0        3.3         7.9  ...
# Yinka Dare                      0.0         3.0        0.0         1.0  ...
# Yogi Ferrell                   29.0        26.0        3.5         8.6  ...
# Yuta Tabuse                     0.0         4.3        0.3         1.5  ...
# Yvon Joseph                     0.0         5.0        0.0         0.0  ...
# Zabian Dowdell                  0.0        12.2        2.1         5.2  ...
# Zach Collins                    1.0        15.2        1.6         4.2  ...
# Zach LaVine                    40.0        24.7        3.7         8.8  ...
# Zach Randolph                   0.0         5.8        1.2         2.6  ...
# Zan Tabak                       0.0         4.9        0.6         1.4  ...
# Zarko Cabarkapa                 4.0        11.6        1.7         4.0  ...
# Zarko Paspalj                   1.0         6.5        1.0         2.8  ...
# Zaza Pachulia                   2.0        11.3        1.2         3.0  ...
# Zeljko Rebraca                  4.0        15.9        2.6         5.1  ...
# Zelmo Beaty                     NaN        24.0        3.7         8.5  ...
# Zendon Hamilton                 0.0         6.3        0.7         3.0  ...
# Zhou Qi                         0.0         5.4        0.3         1.7  ...
# Zoran Dragic                    1.0         4.7        0.7         1.9  ...
# Zoran Planinic                  1.0         9.7        1.1         2.6  ...
# Zydrunas Ilgauskas             81.0        29.0        5.5        10.7  ...
#
#                     blank_y  OWS  DWS   WS  WS/48  blank.1  OBPM  DBPM   BPM  \
# Name
# A.C. Green              NaN  1.4  2.0  3.3  0.103      NaN  -0.5   0.8   0.3
# A.J. Bramlett           NaN -0.2  0.1 -0.2 -0.129      NaN -10.5  -6.3 -16.8
# A.J. English            NaN -0.5  0.7  0.2  0.008      NaN  -2.5  -2.3  -4.8
# A.J. Guyton             NaN  0.4 -0.1  0.3  0.020      NaN  -1.5  -4.4  -5.9
# A.J. Hammons            NaN -0.2  0.2  0.0 -0.001      NaN  -7.5   2.0  -5.6
# A.J. Price              NaN  0.4  0.8  1.2  0.065      NaN   0.2  -2.0  -1.8
# A.J. Wynder             NaN -0.1  0.0  0.0 -0.051      NaN  -5.9  -3.5  -9.4
# Aaron Brooks            NaN  0.6  0.8  1.4  0.112      NaN   0.0  -1.8  -1.8
# Aaron Gordon            NaN  0.3  0.7  1.0  0.060      NaN  -2.8   0.0  -2.8
# Aaron Gray              NaN  0.1  0.8  0.8  0.066      NaN  -2.4   0.4  -2.0
# Aaron Harrison          NaN -0.2  0.1  0.0 -0.014      NaN  -5.6   0.1  -5.5
# Aaron McKie             NaN  0.8  1.2  2.0  0.115      NaN  -1.2   1.3   0.1
# Aaron Miles             NaN -0.2  0.1  0.0 -0.015      NaN  -7.7  -0.5  -8.2
# Aaron Swinson           NaN  0.0  0.0  0.0  0.039      NaN  -2.9  -2.9  -5.8
# Aaron Williams          NaN -0.1  0.0 -0.1 -0.327      NaN -13.7  -4.3 -18.0
# Abdel Nader             NaN -0.4  0.4 -0.1 -0.009      NaN  -5.3  -0.1  -5.4
# Abdul Jeelani           NaN  2.3  1.5  3.8  0.141      NaN   1.0  -0.8   0.2
# Acie Earl               NaN -0.7  0.9  0.2  0.008      NaN  -5.4  -1.7  -7.1
# Acie Law                NaN -0.5  0.4 -0.1 -0.007      NaN  -4.1  -2.6  -6.7
# Adam Harrington         NaN  0.0  0.1  0.0  0.017      NaN  -3.9  -3.2  -7.1
# Adam Keefe              NaN  1.9  1.4  3.3  0.102      NaN  -1.2   0.1  -1.0
# Adam Morrison           NaN -2.2  0.8 -1.5 -0.030      NaN  -3.0  -2.5  -5.5
# Adonal Foyle            NaN -1.0  0.9 -0.1 -0.009      NaN  -6.9   1.6  -5.4
# Adonis Jordan           NaN -0.1  0.0 -0.1 -0.037      NaN  -4.5  -4.2  -8.7
# Adonis Thomas           NaN  0.0  0.0  0.0  0.001      NaN  -4.0  -5.7  -9.7
# Adreian Payne           NaN -0.7  0.2 -0.5 -0.033      NaN  -4.6  -1.3  -5.9
# Adrian Branch           NaN  0.4  0.4  0.7  0.158      NaN   0.5  -0.3   0.2
# Adrian Caldwell         NaN -0.3  0.7  0.4  0.061      NaN  -5.6   1.3  -4.3
# Adrian Dantley          NaN  8.2  1.6  9.8  0.167      NaN   3.5  -1.1   2.5
# Adrian Griffin          NaN  1.8  2.1  3.9  0.098      NaN  -0.3   2.0   1.7
# ...                     ...  ...  ...  ...    ...      ...   ...   ...   ...
# Winston Crite           NaN  0.0  0.2  0.1  0.025      NaN  -3.2  -0.6  -3.8
# Winston Garland         NaN  0.8  0.9  1.7  0.039      NaN  -0.3  -0.9  -1.2
# World B. Free           NaN  0.9  0.6  1.5  0.064      NaN  -0.4  -2.8  -3.3
# Xavier Henry            NaN -0.1  0.3  0.2  0.021      NaN  -3.9  -2.1  -6.0
# Xavier McDaniel         NaN  1.8  3.3  5.1  0.091      NaN   0.8   0.7   1.5
# Xavier Munford          NaN -0.2  0.2  0.1  0.017      NaN  -2.9  -0.1  -3.1
# Xavier Silas            NaN -0.1  0.0 -0.1 -0.131      NaN  -6.8  -3.7 -10.5
# Yakhouba Diawara        NaN -0.2  0.8  0.5  0.021      NaN  -2.3  -0.8  -3.1
# Yao Ming                NaN  5.2  3.5  8.7  0.176      NaN   0.2   1.7   1.9
# Yaroslav Korolev        NaN -0.1  0.1  0.0 -0.013      NaN  -4.8  -1.5  -6.3
# Yi Jianlian             NaN -0.1  0.9  0.7  0.022      NaN  -3.9  -0.7  -4.6
# Yinka Dare              NaN -0.1  0.0  0.0 -0.736      NaN -33.8  -5.5 -39.3
# Yogi Ferrell            NaN  0.8  1.0  1.8  0.072      NaN  -0.1  -0.6  -0.7
# Yuta Tabuse             NaN  0.0  0.0  0.0  0.129      NaN   0.1  -2.7  -2.6
# Yvon Joseph             NaN  0.0  0.0  0.0  0.309      NaN   2.7  -3.6  -0.9
# Zabian Dowdell          NaN -0.4  0.2 -0.1 -0.019      NaN  -3.5  -1.0  -4.6
# Zach Collins            NaN -0.5  0.9  0.4  0.027      NaN  -4.4   1.1  -3.2
# Zach LaVine             NaN -0.7  0.0 -0.7 -0.018      NaN  -1.7  -2.7  -4.5
# Zach Randolph           NaN  0.2  0.3  0.5  0.098      NaN  -1.7  -1.7  -3.4
# Zan Tabak               NaN -0.1  0.2  0.2  0.043      NaN  -5.7  -2.5  -8.2
# Zarko Cabarkapa         NaN -0.7  0.3 -0.4 -0.037      NaN  -4.8  -1.7  -6.5
# Zarko Paspalj           NaN -0.5  0.2 -0.3 -0.072      NaN  -7.3  -1.8  -9.2
# Zaza Pachulia           NaN  0.1  0.2  0.3  0.023      NaN  -4.1  -2.5  -6.6
# Zeljko Rebraca          NaN  1.4  1.9  3.3  0.134      NaN  -2.8   0.7  -2.2
# Zelmo Beaty             NaN  2.1  3.1  5.2  0.131      NaN   NaN   NaN   NaN
# Zendon Hamilton         NaN -0.1  0.0  0.0 -0.119      NaN -12.8 -11.8 -24.6
# Zhou Qi                 NaN -0.3  0.1 -0.2 -0.126      NaN -10.7   0.7 -10.0
# Zoran Dragic            NaN -0.1  0.0 -0.1 -0.042      NaN  -2.5  -4.0  -6.5
# Zoran Planinic          NaN  0.1  0.6  0.7  0.068      NaN  -2.8  -1.4  -4.3
# Zydrunas Ilgauskas      NaN  4.5  4.9  9.4  0.189      NaN   0.3   1.7   2.0
#
#                     VORP
# Name
# A.C. Green           0.9
# A.J. Bramlett       -0.2
# A.J. English        -1.0
# A.J. Guyton         -0.6
# A.J. Hammons        -0.1
# A.J. Price           0.0
# A.J. Wynder         -0.1
# Aaron Brooks         0.0
# Aaron Gordon        -0.2
# Aaron Gray           0.0
# Aaron Harrison      -0.1
# Aaron McKie          0.4
# Aaron Miles         -0.2
# Aaron Swinson        0.0
# Aaron Williams       0.0
# Abdel Nader         -0.2
# Abdul Jeelani        0.7
# Acie Earl           -1.5
# Acie Law            -1.0
# Adam Harrington     -0.1
# Adam Keefe           0.4
# Adam Morrison       -2.0
# Adonal Foyle        -0.6
# Adonis Jordan       -0.1
# Adonis Thomas       -0.1
# Adreian Payne       -0.7
# Adrian Branch        0.1
# Adrian Caldwell     -0.2
# Adrian Dantley       3.2
# Adrian Griffin       1.8
# ...                  ...
# Winston Crite       -0.1
# Winston Garland      0.4
# World B. Free       -0.4
# Xavier Henry        -0.5
# Xavier McDaniel      2.4
# Xavier Munford      -0.1
# Xavier Silas        -0.1
# Yakhouba Diawara    -0.3
# Yao Ming             2.4
# Yaroslav Korolev    -0.1
# Yi Jianlian         -1.1
# Yinka Dare           0.0
# Yogi Ferrell         0.4
# Yuta Tabuse          0.0
# Yvon Joseph          0.0
# Zabian Dowdell      -0.2
# Zach Collins        -0.2
# Zach LaVine         -1.2
# Zach Randolph       -0.1
# Zan Tabak           -0.3
# Zarko Cabarkapa     -0.7
# Zarko Paspalj       -0.3
# Zaza Pachulia       -0.8
# Zeljko Rebraca       0.0
# Zelmo Beaty          NaN
# Zendon Hamilton     -0.1
# Zhou Qi             -0.2
# Zoran Dragic        -0.1
# Zoran Planinic      -0.3
# Zydrunas Ilgauskas   2.4
#
# [3731 rows x 120 columns]
